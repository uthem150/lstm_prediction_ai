# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in d:\anaconda\lib\site-packages (2.4.3)
# Requirement already satisfied: numpy>=1.9.1 in d:\anaconda\lib\site-packages (from keras) (1.24.3)
# Requirement already satisfied: scipy>=0.14 in d:\anaconda\lib\site-packages (from keras) (1.10.1)
# Requirement already satisfied: pyyaml in d:\anaconda\lib\site-packages (from keras) (6.0)
# Requirement already satisfied: h5py in d:\anaconda\lib\site-packages (from keras) (3.7.0)

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in d:\anaconda\lib\site-packages (2.15.0)
# Requirement already satisfied: tensorflow-intel==2.15.0 in d:\anaconda\lib\site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.7.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\kdh\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.23.4)
# Requirement already satisfied: setuptools in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.60.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Collecting keras<2.16,>=2.15.0 (from tensorflow-intel==2.15.0->tensorflow)
#   Obtaining dependency information for keras<2.16,>=2.15.0 from https://files.pythonhosted.org/packages/fc/a7/0d4490de967a67f68a538cc9cdb259bff971c4b5787f7765dc7c8f118f71/keras-2.15.0-py3-none-any.whl.metadata
#   Using cached keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\anaconda\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\anaconda\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.26.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in d:\anaconda\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in d:\anaconda\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\anaconda\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\anaconda\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\anaconda\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\anaconda\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\anaconda\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\anaconda\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.2.2)
# Using cached keras-2.15.0-py3-none-any.whl (1.7 MB)
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: Keras 2.4.3
#     Uninstalling Keras-2.4.3:
#       Successfully uninstalled Keras-2.4.3
# Successfully installed keras-2.15.0

# %% [markdown]
# # 기본 (shuffle, rmsprop)

# %%
import pandas as pd # csv파일 로드용
import numpy as np # 행렬 연산용
import matplotlib.pyplot as plt # 데이터 시각화

#딥러닝 모델 작성 keras
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense, Activation
# from keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
import datetime



# Load Dataset
data = pd.read_csv('samsung.csv') #데이터 로드


## Compute Mid Price
high_prices = data['High'].values
low_prices = data['Low'].values
mid_prices = (high_prices + low_prices) / 2 # 중간 가격 계산


# Create Windows
seq_len = 50
sequence_length = seq_len + 1 # 50개의 데이터 + 예측할 데이터 1개 (윈도우 하나에 51개의 데이터 저장)

result = []
for index in range(len(mid_prices) - sequence_length):
    result.append(mid_prices[index: index + sequence_length])




# Normalize Data (데이터 정규)
normalized_data = []
for window in result:
    normalized_window = [((float(p) / float(window[0])) - 1) for p in window]
    normalized_data.append(normalized_window)

result = np.array(normalized_data)

# split train and test data
row = int(round(result.shape[0] * 0.8))
train = result[:row, :] # 전체 데이터의 80%를 train set으로 분리함
np.random.shuffle(train) # training set은 랜덤으로 섞어주는게 좋음.

# 윈도우마다 51개의 데이터가 들어있고
# 50개의 데이터를 input으로 나머지 1일의 데이터를 예측할 것임

x_train = train[:, :-1] # 50개
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = train[:, -1] # 마지막 1개

x_test = result[row:, :-1] # 50개
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
y_test = result[row:, -1] # 마지막 1개

x_train.shape, x_test.shape


# Build a Model
    
model = Sequential() # sequential이라는 class를 사용

model.add(LSTM(50, return_sequences=True, input_shape=(50, 1))) # input 50개 (units 50개)

model.add(LSTM(64, return_sequences=False)) # (units 64개)

model.add(Dense(1, activation='linear')) # ouput은 1개 - 다음날의 데이터 예측

model.compile(loss='mse', optimizer='rmsprop') # 손실 함수는 Mean Squared Error 사용, optimizer는 rmsprop 사용

model.summary()


# Training
model.fit(x_train, y_train,
    validation_data=(x_test, y_test),
    batch_size=10,
    epochs=20)


# Prediction
pred = model.predict(x_test)

fig = plt.figure(facecolor='white', figsize=(20, 10)) # 그래프를 생성 facecolor='white' 배경색을 흰색, figsize=(20, 10) 그래프의 크기를 설정
ax = fig.add_subplot(111) # 111은 그리드 파라미터로, 1x1 그리드의 첫 번째 서브플롯
ax.plot(y_test, label='True')
ax.plot(pred, label='Prediction')
ax.legend() # 범례 추가
plt.show()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_46 (LSTM)              (None, 50, 50)            10400
#
#  lstm_47 (LSTM)              (None, 64)                29440
#
#  dense_23 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 39905 (155.88 KB)
# Trainable params: 39905 (155.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 95/95 [==============================] - 9s 57ms/step - loss: 0.0024 - val_loss: 6.5466e-04
# Epoch 2/20
# 95/95 [==============================] - 4s 37ms/step - loss: 0.0013 - val_loss: 5.4848e-04
# Epoch 3/20
# 95/95 [==============================] - 2s 19ms/step - loss: 0.0011 - val_loss: 4.3784e-04
# Epoch 4/20
# 95/95 [==============================] - 2s 24ms/step - loss: 9.8755e-04 - val_loss: 5.2459e-04
# Epoch 5/20
# 95/95 [==============================] - 2s 25ms/step - loss: 8.8647e-04 - val_loss: 0.0014
# Epoch 6/20
# 95/95 [==============================] - 2s 22ms/step - loss: 8.1955e-04 - val_loss: 4.2180e-04
# Epoch 7/20
# 95/95 [==============================] - 2s 22ms/step - loss: 8.2000e-04 - val_loss: 3.3936e-04
# Epoch 8/20
# 95/95 [==============================] - 2s 24ms/step - loss: 7.5481e-04 - val_loss: 3.2836e-04
# Epoch 9/20
# 95/95 [==============================] - 2s 26ms/step - loss: 7.1579e-04 - val_loss: 8.3045e-04
# Epoch 10/20
# 95/95 [==============================] - 2s 17ms/step - loss: 7.1717e-04 - val_loss: 3.0598e-04
# Epoch 11/20
# 95/95 [==============================] - 3s 28ms/step - loss: 6.8434e-04 - val_loss: 4.2580e-04
# Epoch 12/20
# 95/95 [==============================] - 2s 24ms/step - loss: 6.3138e-04 - val_loss: 5.1010e-04
# Epoch 13/20
# 95/95 [==============================] - 4s 39ms/step - loss: 6.2097e-04 - val_loss: 3.8496e-04
# Epoch 14/20
# 95/95 [==============================] - 4s 44ms/step - loss: 6.2080e-04 - val_loss: 3.0917e-04
# Epoch 15/20
# 95/95 [==============================] - 4s 44ms/step - loss: 5.8418e-04 - val_loss: 3.3853e-04
# Epoch 16/20
# 95/95 [==============================] - 2s 23ms/step - loss: 5.6509e-04 - val_loss: 5.1516e-04
# Epoch 17/20
# 95/95 [==============================] - 2s 22ms/step - loss: 5.6573e-04 - val_loss: 5.8977e-04
# Epoch 18/20
# 95/95 [==============================] - 3s 31ms/step - loss: 5.4985e-04 - val_loss: 2.5075e-04
# Epoch 19/20
# 95/95 [==============================] - 4s 43ms/step - loss: 5.4768e-04 - val_loss: 2.9773e-04
# Epoch 20/20
# 95/95 [==============================] - 4s 39ms/step - loss: 5.2380e-04 - val_loss: 2.6509e-04
# 8/8 [==============================] - 1s 20ms/step

# %% [markdown]
# # adam optimizer사용

# %%
import pandas as pd # csv파일 로드용
import numpy as np # 행렬 연산용
import matplotlib.pyplot as plt # 데이터 시각화

#딥러닝 모델 작성 keras
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense, Activation
# from keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
import datetime



# Load Dataset
data = pd.read_csv('samsung.csv') #데이터 로드


## Compute Mid Price
high_prices = data['High'].values
low_prices = data['Low'].values
mid_prices = (high_prices + low_prices) / 2 # 중간 가격 계산


# Create Windows
seq_len = 50
sequence_length = seq_len + 1 # 50개의 데이터 + 예측할 데이터 1개 (윈도우 하나에 51개의 데이터 저장)

result = []
for index in range(len(mid_prices) - sequence_length):
    result.append(mid_prices[index: index + sequence_length])


# Normalize Data (데이터 정규)
normalized_data = []
for window in result:
    normalized_window = [((float(p) / float(window[0])) - 1) for p in window]
    normalized_data.append(normalized_window)

result = np.array(normalized_data)

# split train and test data
row = int(round(result.shape[0] * 0.8))
train = result[:row, :] # 전체 데이터의 80%를 train set으로 분리함
np.random.shuffle(train) # training set은 랜덤으로 섞어주는게 좋음.

# 윈도우마다 51개의 데이터가 들어있고
# 50개의 데이터를 input으로 나머지 1일의 데이터를 예측할 것임

x_train = train[:, :-1] # 50개
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = train[:, -1] # 마지막 1개

x_test = result[row:, :-1] # 50개
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
y_test = result[row:, -1] # 마지막 1개

x_train.shape, x_test.shape


# Build a Model
    
model = Sequential() # sequential이라는 class를 사용

model.add(LSTM(50, return_sequences=True, input_shape=(50, 1))) # input 50개 (units 50개)

model.add(LSTM(64, return_sequences=False)) # (units 64개)

model.add(Dense(1, activation='linear')) # ouput은 1개 - 다음날의 데이터 예측

model.compile(loss='mse', optimizer='adam') # 손실 함수는 Mean Squared Error 사용, optimizer는 rmsprop 사용

model.summary()


# Training
model.fit(x_train, y_train,
    validation_data=(x_test, y_test),
    batch_size=10,
    epochs=20)


# Prediction
pred = model.predict(x_test)

fig = plt.figure(facecolor='white', figsize=(20, 10)) # 그래프를 생성 facecolor='white' 배경색을 흰색, figsize=(20, 10) 그래프의 크기를 설정
ax = fig.add_subplot(111) # 111은 그리드 파라미터로, 1x1 그리드의 첫 번째 서브플롯
ax.plot(y_test, label='True')
ax.plot(pred, label='Prediction')
ax.legend() # 범례 추가
plt.show()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_18 (LSTM)              (None, 50, 50)            10400
#
#  lstm_19 (LSTM)              (None, 64)                29440
#
#  dense_9 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 39905 (155.88 KB)
# Trainable params: 39905 (155.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 95/95 [==============================] - 11s 63ms/step - loss: 0.0027 - val_loss: 5.2489e-04
# Epoch 2/20
# 95/95 [==============================] - 4s 44ms/step - loss: 0.0010 - val_loss: 4.4503e-04
# Epoch 3/20
# 95/95 [==============================] - 4s 37ms/step - loss: 9.0740e-04 - val_loss: 4.1768e-04
# Epoch 4/20
# 95/95 [==============================] - 4s 40ms/step - loss: 8.0088e-04 - val_loss: 3.1977e-04
# Epoch 5/20
# 95/95 [==============================] - 2s 22ms/step - loss: 6.9362e-04 - val_loss: 2.8551e-04
# Epoch 6/20
# 95/95 [==============================] - 3s 28ms/step - loss: 5.7948e-04 - val_loss: 3.2557e-04
# Epoch 7/20
# 95/95 [==============================] - 2s 17ms/step - loss: 5.3261e-04 - val_loss: 2.7186e-04
# Epoch 8/20
# 95/95 [==============================] - 2s 22ms/step - loss: 4.9159e-04 - val_loss: 2.4153e-04
# Epoch 9/20
# 95/95 [==============================] - 2s 24ms/step - loss: 4.9927e-04 - val_loss: 2.4362e-04
# Epoch 10/20
# 95/95 [==============================] - 3s 26ms/step - loss: 4.1064e-04 - val_loss: 1.9789e-04
# Epoch 11/20
# 95/95 [==============================] - 3s 32ms/step - loss: 3.7971e-04 - val_loss: 1.9025e-04
# Epoch 12/20
# 95/95 [==============================] - 4s 44ms/step - loss: 4.0150e-04 - val_loss: 2.2317e-04
# Epoch 13/20
# 95/95 [==============================] - 4s 39ms/step - loss: 3.4018e-04 - val_loss: 1.9423e-04
# Epoch 14/20
# 95/95 [==============================] - 2s 18ms/step - loss: 3.3628e-04 - val_loss: 1.5850e-04
# Epoch 15/20
# 95/95 [==============================] - 3s 27ms/step - loss: 3.1524e-04 - val_loss: 2.1062e-04
# Epoch 16/20
# 95/95 [==============================] - 2s 20ms/step - loss: 3.2589e-04 - val_loss: 1.7840e-04
# Epoch 17/20
# 95/95 [==============================] - 3s 29ms/step - loss: 3.0338e-04 - val_loss: 1.5181e-04
# Epoch 18/20
# 95/95 [==============================] - 2s 21ms/step - loss: 2.7602e-04 - val_loss: 1.3871e-04
# Epoch 19/20
# 95/95 [==============================] - 2s 19ms/step - loss: 2.6746e-04 - val_loss: 1.6350e-04
# Epoch 20/20
# 95/95 [==============================] - 2s 23ms/step - loss: 2.7379e-04 - val_loss: 1.5755e-04
# 8/8 [==============================] - 1s 9ms/step

# %% [markdown]
# # 데이터 셔플 안함

# %%
import pandas as pd # csv파일 로드용
import numpy as np # 행렬 연산용
import matplotlib.pyplot as plt # 데이터 시각화

#딥러닝 모델 작성 keras
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense, Activation
# from keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
import datetime



# Load Dataset
data = pd.read_csv('samsung.csv') #데이터 로드


## Compute Mid Price
high_prices = data['High'].values
low_prices = data['Low'].values
mid_prices = (high_prices + low_prices) / 2 # 중간 가격 계산


# Create Windows
seq_len = 50
sequence_length = seq_len + 1 # 50개의 데이터 + 예측할 데이터 1개 (윈도우 하나에 51개의 데이터 저장)

result = []
for index in range(len(mid_prices) - sequence_length):
    result.append(mid_prices[index: index + sequence_length])


# Normalize Data (데이터 정규)
normalized_data = []
for window in result:
    normalized_window = [((float(p) / float(window[0])) - 1) for p in window]
    normalized_data.append(normalized_window)

result = np.array(normalized_data)

# split train and test data
row = int(round(result.shape[0] * 0.8))
train = result[:row, :] # 전체 데이터의 80%를 train set으로 분리함

# 윈도우마다 51개의 데이터가 들어있고
# 50개의 데이터를 input으로 나머지 1일의 데이터를 예측할 것임

x_train = train[:, :-1] # 50개
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = train[:, -1] # 마지막 1개

x_test = result[row:, :-1] # 50개
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
y_test = result[row:, -1] # 마지막 1개

x_train.shape, x_test.shape


# Build a Model
    
model = Sequential() # sequential이라는 class를 사용

model.add(LSTM(50, return_sequences=True, input_shape=(50, 1))) # input 50개 (units 50개)

model.add(LSTM(64, return_sequences=False)) # (units 64개)

model.add(Dense(1, activation='linear')) # ouput은 1개 - 다음날의 데이터 예측

model.compile(loss='mse', optimizer='adam') # 손실 함수는 Mean Squared Error 사용, optimizer는 rmsprop 사용

model.summary()


# Training
model.fit(x_train, y_train,
    validation_data=(x_test, y_test),
    batch_size=10,
    epochs=20)


# Prediction
pred = model.predict(x_test)

fig = plt.figure(facecolor='white', figsize=(20, 10)) # 그래프를 생성 facecolor='white' 배경색을 흰색, figsize=(20, 10) 그래프의 크기를 설정
ax = fig.add_subplot(111) # 111은 그리드 파라미터로, 1x1 그리드의 첫 번째 서브플롯
ax.plot(y_test, label='True')
ax.plot(pred, label='Prediction')
ax.legend() # 범례 추가
plt.show()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_14 (LSTM)              (None, 50, 50)            10400
#
#  lstm_15 (LSTM)              (None, 64)                29440
#
#  dense_7 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 39905 (155.88 KB)
# Trainable params: 39905 (155.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 95/95 [==============================] - 7s 30ms/step - loss: 0.0022 - val_loss: 5.9015e-04
# Epoch 2/20
# 95/95 [==============================] - 2s 20ms/step - loss: 9.7201e-04 - val_loss: 4.8332e-04
# Epoch 3/20
# 95/95 [==============================] - 2s 23ms/step - loss: 8.4074e-04 - val_loss: 3.6856e-04
# Epoch 4/20
# 95/95 [==============================] - 3s 29ms/step - loss: 7.5382e-04 - val_loss: 2.9741e-04
# Epoch 5/20
# 95/95 [==============================] - 2s 23ms/step - loss: 6.0665e-04 - val_loss: 2.8937e-04
# Epoch 6/20
# 95/95 [==============================] - 2s 22ms/step - loss: 5.2776e-04 - val_loss: 2.4536e-04
# Epoch 7/20
# 95/95 [==============================] - 3s 28ms/step - loss: 5.1575e-04 - val_loss: 3.7750e-04
# Epoch 8/20
# 95/95 [==============================] - 2s 20ms/step - loss: 4.9845e-04 - val_loss: 2.5165e-04
# Epoch 9/20
# 95/95 [==============================] - 3s 29ms/step - loss: 4.2162e-04 - val_loss: 2.4322e-04
# Epoch 10/20
# 95/95 [==============================] - 2s 23ms/step - loss: 4.2595e-04 - val_loss: 1.8363e-04
# Epoch 11/20
# 95/95 [==============================] - 4s 38ms/step - loss: 3.2641e-04 - val_loss: 1.8130e-04
# Epoch 12/20
# 95/95 [==============================] - 4s 39ms/step - loss: 3.4101e-04 - val_loss: 1.6080e-04
# Epoch 13/20
# 95/95 [==============================] - 3s 36ms/step - loss: 2.9687e-04 - val_loss: 1.5672e-04
# Epoch 14/20
# 95/95 [==============================] - 3s 35ms/step - loss: 3.0109e-04 - val_loss: 2.0455e-04
# Epoch 15/20
# 95/95 [==============================] - 3s 37ms/step - loss: 2.8912e-04 - val_loss: 1.3462e-04
# Epoch 16/20
# 95/95 [==============================] - 4s 46ms/step - loss: 2.8048e-04 - val_loss: 1.3290e-04
# Epoch 17/20
# 95/95 [==============================] - 4s 47ms/step - loss: 2.6725e-04 - val_loss: 1.6526e-04
# Epoch 18/20
# 95/95 [==============================] - 4s 41ms/step - loss: 2.7257e-04 - val_loss: 1.3920e-04
# Epoch 19/20
# 95/95 [==============================] - 4s 43ms/step - loss: 2.6534e-04 - val_loss: 1.3193e-04
# Epoch 20/20
# 95/95 [==============================] - 4s 43ms/step - loss: 2.5370e-04 - val_loss: 1.3283e-04
# 8/8 [==============================] - 1s 23ms/step

# %%
# 미래 시각화

# %%
import pandas as pd # csv파일 로드용
import numpy as np # 행렬 연산용
import matplotlib.pyplot as plt # 데이터 시각화

#딥러닝 모델 작성 keras
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense, Activation
# from keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
import datetime



# Load Dataset
data = pd.read_csv('samsung.csv') #데이터 로드


## Compute Mid Price
high_prices = data['High'].values
low_prices = data['Low'].values
mid_prices = (high_prices + low_prices) / 2 # 중간 가격 계산


# Create Windows
seq_len = 50
sequence_length = seq_len + 1 # 50개의 데이터 + 예측할 데이터 1개 (윈도우 하나에 51개의 데이터 저장)

result = []
for index in range(len(mid_prices) - sequence_length):
    result.append(mid_prices[index: index + sequence_length])


# Normalize Data (데이터 정규)
normalized_data = []
for window in result:
    normalized_window = [((float(p) / float(window[0])) - 1) for p in window]
    normalized_data.append(normalized_window)

result = np.array(normalized_data)

# split train and test data
row = int(round(result.shape[0] * 0.8))
train = result[:row, :] # 전체 데이터의 80%를 train set으로 분리함

# 윈도우마다 51개의 데이터가 들어있고
# 50개의 데이터를 input으로 나머지 1일의 데이터를 예측할 것임

x_train = train[:, :-1] # 50개
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = train[:, -1] # 마지막 1개

x_test = result[row:, :-1] # 50개
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
y_test = result[row:, -1] # 마지막 1개

x_train.shape, x_test.shape


# Build a Model
    
model = Sequential() # sequential이라는 class를 사용

model.add(LSTM(50, return_sequences=True, input_shape=(50, 1))) # input 50개 (units 50개)

model.add(LSTM(64, return_sequences=False)) # (units 64개)

model.add(Dense(1, activation='linear')) # ouput은 1개 - 다음날의 데이터 예측

model.compile(loss='mse', optimizer='adam') # 손실 함수는 Mean Squared Error 사용, optimizer는 rmsprop 사용

model.summary()


# Training
model.fit(x_train, y_train,
    validation_data=(x_test, y_test),
    batch_size=10,
    epochs=20)


# 예측을 위한 마지막 50일 데이터 추출
last_50_days = x_test[-50:] 

# 추가로 예측하려는 기간 설정
forecast_period = 30  # 30일치 예측

# 예측 결과를 저장할 리스트 생성
forecast_result = []

for _ in range(forecast_period):
    # 마지막 50일 데이터를 모델에 넣어 예측값 생성
    prediction = model.predict(last_50_days.reshape(-1, 50, 1))
    
    # 예측값을 결과 리스트에 추가
    forecast_result.append(prediction[0])
    
    # 마지막 50일 데이터에 예측값 추가 및 가장 오래된 데이터 삭제
    last_50_days = np.insert(last_50_days[1:], -1, prediction, axis=0)

# 그래프 그리기
fig = plt.figure(facecolor='white', figsize=(20, 10))
ax = fig.add_subplot(111)
ax.plot(np.arange(50), y_test[-50:], label='True')
ax.plot(np.arange(50, 50+forecast_period), forecast_result, label='Forecast')
ax.legend()
plt.show()
# Out:
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_50 (LSTM)              (None, 50, 50)            10400
#
#  lstm_51 (LSTM)              (None, 64)                29440
#
#  dense_25 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 39905 (155.88 KB)
# Trainable params: 39905 (155.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 95/95 [==============================] - 8s 46ms/step - loss: 0.0016 - val_loss: 4.5366e-04
# Epoch 2/20
# 95/95 [==============================] - 2s 19ms/step - loss: 8.3809e-04 - val_loss: 3.5537e-04
# Epoch 3/20
# 95/95 [==============================] - 2s 23ms/step - loss: 7.0249e-04 - val_loss: 3.4507e-04
# Epoch 4/20
# 95/95 [==============================] - 3s 30ms/step - loss: 6.2170e-04 - val_loss: 2.8089e-04
# Epoch 5/20
# 95/95 [==============================] - 2s 19ms/step - loss: 5.1937e-04 - val_loss: 2.4008e-04
# Epoch 6/20
# 95/95 [==============================] - 2s 23ms/step - loss: 4.4529e-04 - val_loss: 2.6657e-04
# Epoch 7/20
# 95/95 [==============================] - 2s 21ms/step - loss: 4.3525e-04 - val_loss: 3.0034e-04
# Epoch 8/20
# 95/95 [==============================] - 3s 27ms/step - loss: 3.8108e-04 - val_loss: 2.1821e-04
# Epoch 9/20
# 95/95 [==============================] - 2s 19ms/step - loss: 3.8098e-04 - val_loss: 1.6718e-04
# Epoch 10/20
# 95/95 [==============================] - 4s 38ms/step - loss: 3.4004e-04 - val_loss: 1.6717e-04
# Epoch 11/20
# 95/95 [==============================] - 2s 21ms/step - loss: 2.9063e-04 - val_loss: 1.5013e-04
# Epoch 12/20
# 95/95 [==============================] - 2s 21ms/step - loss: 3.0393e-04 - val_loss: 1.8273e-04
# Epoch 13/20
# 95/95 [==============================] - 3s 29ms/step - loss: 2.9530e-04 - val_loss: 1.4733e-04
# Epoch 14/20
# 95/95 [==============================] - 3s 30ms/step - loss: 2.7894e-04 - val_loss: 1.3532e-04
# Epoch 15/20
# 95/95 [==============================] - 2s 18ms/step - loss: 2.5939e-04 - val_loss: 1.2821e-04
# Epoch 16/20
# 95/95 [==============================] - 3s 31ms/step - loss: 2.6054e-04 - val_loss: 1.4133e-04
# Epoch 17/20
# 95/95 [==============================] - 3s 36ms/step - loss: 2.5312e-04 - val_loss: 1.2556e-04
# Epoch 18/20
# 95/95 [==============================] - 4s 39ms/step - loss: 2.3931e-04 - val_loss: 1.3242e-04
# Epoch 19/20
# 95/95 [==============================] - 4s 41ms/step - loss: 2.4225e-04 - val_loss: 1.4065e-04
# Epoch 20/20
# 95/95 [==============================] - 4s 38ms/step - loss: 2.4770e-04 - val_loss: 1.5673e-04
# 2/2 [==============================] - 1s 22ms/step
# 2/2 [==============================] - 0s 14ms/step
# 2/2 [==============================] - 0s 11ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 11ms/step
# 2/2 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 15ms/step
# 2/2 [==============================] - 0s 15ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 29ms/step

# %%
import pandas as pd # csv파일 로드용
import numpy as np # 행렬 연산용
import matplotlib.pyplot as plt # 데이터 시각화

#딥러닝 모델 작성 keras
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense, Activation
# from keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
import datetime



# Load Dataset
data = pd.read_csv('samsung.csv') #데이터 로드

# 날짜 컬럼을 datetime 타입으로 변환
data['Date'] = pd.to_datetime(data['Date'])

# 인덱스를 날짜로 설정
data.set_index('Date', inplace=True)

## Compute Mid Price
high_prices = data['High'].values
low_prices = data['Low'].values
mid_prices = (high_prices + low_prices) / 2 # 중간 가격 계산


# Create Windows
seq_len = 50
sequence_length = seq_len + 1 # 50개의 데이터 + 예측할 데이터 1개 (윈도우 하나에 51개의 데이터 저장)

result = []
for index in range(len(mid_prices) - sequence_length):
    result.append(mid_prices[index: index + sequence_length])


# Normalize Data (데이터 정규)
normalized_data = []
for window in result:
    normalized_window = [((float(p) / float(window[0])) - 1) for p in window]
    normalized_data.append(normalized_window)

result = np.array(normalized_data)

# split train and test data
row = int(round(result.shape[0] * 0.8))
train = result[:row, :] # 전체 데이터의 80%를 train set으로 분리함

# 윈도우마다 51개의 데이터가 들어있고
# 50개의 데이터를 input으로 나머지 1일의 데이터를 예측할 것임

x_train = train[:, :-1] # 50개
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = train[:, -1] # 마지막 1개

x_test = result[row:, :-1] # 50개
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
y_test = result[row:, -1] # 마지막 1개

x_train.shape, x_test.shape


# Build a Model
    
model = Sequential() # sequential이라는 class를 사용

model.add(LSTM(50, return_sequences=True, input_shape=(50, 1))) # input 50개 (units 50개)

model.add(LSTM(64, return_sequences=False)) # (units 64개)

model.add(Dense(1, activation='linear')) # ouput은 1개 - 다음날의 데이터 예측

model.compile(loss='mse', optimizer='adam') # 손실 함수는 Mean Squared Error 사용, optimizer는 rmsprop 사용

model.summary()


# Training
model.fit(x_train, y_train,
    validation_data=(x_test, y_test),
    batch_size=10,
    epochs=20)


# Prediction
pred = model.predict(x_test)

fig = plt.figure(facecolor='white', figsize=(20, 10)) 
ax = fig.add_subplot(111) 

# x축 데이터 생성
x_range = data.index[row: row + len(y_test)]

ax.plot(x_range, y_test, label='True')
ax.plot(x_range, pred, label='Prediction')
ax.legend()
plt.show()
# Out:
# Model: "sequential_27"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_54 (LSTM)              (None, 50, 50)            10400
#
#  lstm_55 (LSTM)              (None, 64)                29440
#
#  dense_27 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 39905 (155.88 KB)
# Trainable params: 39905 (155.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 95/95 [==============================] - 8s 53ms/step - loss: 0.0023 - val_loss: 5.3723e-04
# Epoch 2/20
# 95/95 [==============================] - 4s 42ms/step - loss: 0.0011 - val_loss: 4.2241e-04
# Epoch 3/20
# 95/95 [==============================] - 4s 41ms/step - loss: 8.6388e-04 - val_loss: 4.1264e-04
# Epoch 4/20
# 95/95 [==============================] - 4s 43ms/step - loss: 7.5958e-04 - val_loss: 4.6995e-04
# Epoch 5/20
# 95/95 [==============================] - 4s 43ms/step - loss: 6.4934e-04 - val_loss: 3.1427e-04
# Epoch 6/20
# 95/95 [==============================] - 4s 44ms/step - loss: 5.9985e-04 - val_loss: 2.6370e-04
# Epoch 7/20
# 95/95 [==============================] - 2s 19ms/step - loss: 5.1480e-04 - val_loss: 2.5099e-04
# Epoch 8/20
# 95/95 [==============================] - 2s 21ms/step - loss: 4.8367e-04 - val_loss: 2.2262e-04
# Epoch 9/20
# 95/95 [==============================] - 2s 24ms/step - loss: 4.2116e-04 - val_loss: 2.0983e-04
# Epoch 10/20
# 95/95 [==============================] - 2s 21ms/step - loss: 4.0955e-04 - val_loss: 1.9474e-04
# Epoch 11/20
# 95/95 [==============================] - 2s 22ms/step - loss: 3.7703e-04 - val_loss: 1.8258e-04
# Epoch 12/20
# 95/95 [==============================] - 3s 28ms/step - loss: 3.5743e-04 - val_loss: 1.7360e-04
# Epoch 13/20
# 95/95 [==============================] - 2s 20ms/step - loss: 2.9848e-04 - val_loss: 1.5730e-04
# Epoch 14/20
# 95/95 [==============================] - 3s 30ms/step - loss: 3.0226e-04 - val_loss: 1.7475e-04
# Epoch 15/20
# 95/95 [==============================] - 4s 39ms/step - loss: 2.7593e-04 - val_loss: 1.4147e-04
# Epoch 16/20
# 95/95 [==============================] - 4s 41ms/step - loss: 2.6344e-04 - val_loss: 1.7849e-04
# Epoch 17/20
# 95/95 [==============================] - 4s 43ms/step - loss: 2.5884e-04 - val_loss: 1.6499e-04
# Epoch 18/20
# 95/95 [==============================] - 4s 38ms/step - loss: 2.7701e-04 - val_loss: 2.1034e-04
# Epoch 19/20
# 95/95 [==============================] - 4s 40ms/step - loss: 2.5728e-04 - val_loss: 1.5510e-04
# Epoch 20/20
# 95/95 [==============================] - 4s 44ms/step - loss: 2.4878e-04 - val_loss: 2.0475e-04
# 8/8 [==============================] - 1s 23ms/step

# %%
import pandas as pd # csv파일 로드용
import numpy as np # 행렬 연산용
import matplotlib.pyplot as plt # 데이터 시각화

#딥러닝 모델 작성 keras
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense, Activation
# from keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
import datetime



# Load Dataset
data = pd.read_csv('samsung.csv') #데이터 로드

# 날짜 컬럼을 datetime 타입으로 변환
data['Date'] = pd.to_datetime(data['Date'])

# 인덱스를 날짜로 설정
data.set_index('Date', inplace=True)

## Compute Mid Price
high_prices = data['High'].values
low_prices = data['Low'].values
mid_prices = (high_prices + low_prices) / 2 # 중간 가격 계산


# Create Windows
seq_len = 50
sequence_length = seq_len + 1 # 50개의 데이터 + 예측할 데이터 1개 (윈도우 하나에 51개의 데이터 저장)

result = []
for index in range(len(mid_prices) - sequence_length):
    result.append(mid_prices[index: index + sequence_length])


# Normalize Data (데이터 정규)
normalized_data = []
for window in result:
    normalized_window = [((float(p) / float(window[0])) - 1) for p in window]
    normalized_data.append(normalized_window)

result = np.array(normalized_data)

# split train and test data
row = int(round(result.shape[0] * 0.80))
train = result[:row, :] # 전체 데이터의 80%를 train set으로 분리함

# 윈도우마다 51개의 데이터가 들어있고
# 50개의 데이터를 input으로 나머지 1일의 데이터를 예측할 것임

x_train = train[:, :-1] # 50개
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = train[:, -1] # 마지막 1개

x_test = result[row:, :-1] # 50개
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
y_test = result[row:, -1] # 마지막 1개

x_train.shape, x_test.shape


# Build a Model
    
model = Sequential() # sequential이라는 class를 사용

model.add(LSTM(50, return_sequences=True, input_shape=(50, 1))) # input 50개 (units 50개)

model.add(LSTM(64, return_sequences=False)) # (units 64개)

model.add(Dense(1, activation='linear')) # ouput은 1개 - 다음날의 데이터 예측

model.compile(loss='mse', optimizer='adam') # 손실 함수는 Mean Squared Error 사용, optimizer는 rmsprop 사용

model.summary()


# Training
model.fit(x_train, y_train,
    validation_data=(x_test, y_test),
    batch_size=10,
    epochs=20)


# Prediction
pred = model.predict(x_test)

fig = plt.figure(facecolor='white', figsize=(20, 10)) 
ax = fig.add_subplot(111) 

# x축 데이터 생성
x_range = data.index[row+seq_len : row + len(y_test)+seq_len]

ax.plot(x_range, y_test, label='True')
ax.plot(x_range, pred, label='Prediction')
ax.legend()
plt.show()
# Out:
# Model: "sequential_43"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_86 (LSTM)              (None, 50, 50)            10400
#
#  lstm_87 (LSTM)              (None, 64)                29440
#
#  dense_43 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 39905 (155.88 KB)
# Trainable params: 39905 (155.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 95/95 [==============================] - 8s 49ms/step - loss: 0.0020 - val_loss: 7.1512e-04
# Epoch 2/20
# 95/95 [==============================] - 3s 26ms/step - loss: 0.0011 - val_loss: 5.5079e-04
# Epoch 3/20
# 95/95 [==============================] - 2s 21ms/step - loss: 9.1942e-04 - val_loss: 3.3585e-04
# Epoch 4/20
# 95/95 [==============================] - 2s 21ms/step - loss: 7.3323e-04 - val_loss: 2.9724e-04
# Epoch 5/20
# 95/95 [==============================] - 3s 29ms/step - loss: 6.2073e-04 - val_loss: 2.9004e-04
# Epoch 6/20
# 95/95 [==============================] - 3s 35ms/step - loss: 5.5663e-04 - val_loss: 2.5290e-04
# Epoch 7/20
# 95/95 [==============================] - 3s 30ms/step - loss: 5.9164e-04 - val_loss: 2.4844e-04
# Epoch 8/20
# 95/95 [==============================] - 3s 31ms/step - loss: 4.6714e-04 - val_loss: 2.2362e-04
# Epoch 9/20
# 95/95 [==============================] - 3s 32ms/step - loss: 4.5518e-04 - val_loss: 2.2504e-04
# Epoch 10/20
# 95/95 [==============================] - 3s 31ms/step - loss: 3.8583e-04 - val_loss: 2.1074e-04
# Epoch 11/20
# 95/95 [==============================] - 3s 31ms/step - loss: 3.4868e-04 - val_loss: 1.8854e-04
# Epoch 12/20
# 95/95 [==============================] - 3s 31ms/step - loss: 3.5793e-04 - val_loss: 1.8083e-04
# Epoch 13/20
# 95/95 [==============================] - 2s 21ms/step - loss: 2.9508e-04 - val_loss: 1.5022e-04
# Epoch 14/20
# 95/95 [==============================] - 2s 26ms/step - loss: 2.8980e-04 - val_loss: 1.5472e-04
# Epoch 15/20
# 95/95 [==============================] - 3s 27ms/step - loss: 2.9031e-04 - val_loss: 1.5654e-04
# Epoch 16/20
# 95/95 [==============================] - 3s 36ms/step - loss: 2.7711e-04 - val_loss: 1.3936e-04
# Epoch 17/20
# 95/95 [==============================] - 4s 38ms/step - loss: 2.4215e-04 - val_loss: 2.0928e-04
# Epoch 18/20
# 95/95 [==============================] - 3s 36ms/step - loss: 2.5796e-04 - val_loss: 1.4269e-04
# Epoch 19/20
# 95/95 [==============================] - 3s 37ms/step - loss: 2.7062e-04 - val_loss: 1.2451e-04
# Epoch 20/20
# 95/95 [==============================] - 3s 37ms/step - loss: 2.7847e-04 - val_loss: 1.2852e-04
# 8/8 [==============================] - 1s 29ms/step

# %%
# x축 데이터 생성
x_range = data.index[row+seq_len : row + len(y_test)+seq_len]

ax.plot(x_range, y_test, label='True')
ax.plot(x_range, pred, label='Prediction')
ax.legend()
plt.show()
# Out:
# Model: "sequential_45"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_90 (LSTM)              (None, 50, 50)            10400
#
#  lstm_91 (LSTM)              (None, 64)                29440
#
#  dense_45 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 39905 (155.88 KB)
# Trainable params: 39905 (155.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 95/95 [==============================] - 8s 54ms/step - loss: 0.0021 - val_loss: 4.5223e-04
# Epoch 2/20
# 95/95 [==============================] - 4s 41ms/step - loss: 9.2220e-04 - val_loss: 4.4736e-04
# Epoch 3/20
# 95/95 [==============================] - 4s 43ms/step - loss: 7.5510e-04 - val_loss: 3.0522e-04
# Epoch 4/20
# 95/95 [==============================] - 4s 39ms/step - loss: 6.6141e-04 - val_loss: 3.2204e-04
# Epoch 5/20
# 95/95 [==============================] - 4s 43ms/step - loss: 5.6865e-04 - val_loss: 2.4416e-04
# Epoch 6/20
# 95/95 [==============================] - 4s 43ms/step - loss: 4.9796e-04 - val_loss: 3.0410e-04
# Epoch 7/20
# 95/95 [==============================] - 4s 40ms/step - loss: 4.8003e-04 - val_loss: 2.1252e-04
# Epoch 8/20
# 95/95 [==============================] - 4s 42ms/step - loss: 4.0063e-04 - val_loss: 2.0701e-04
# Epoch 9/20
# 95/95 [==============================] - 4s 43ms/step - loss: 3.7971e-04 - val_loss: 2.0546e-04
# Epoch 10/20
# 95/95 [==============================] - 4s 40ms/step - loss: 3.5489e-04 - val_loss: 1.8704e-04
# Epoch 11/20
# 95/95 [==============================] - 4s 41ms/step - loss: 3.4950e-04 - val_loss: 1.7476e-04
# Epoch 12/20
# 95/95 [==============================] - 4s 45ms/step - loss: 3.1840e-04 - val_loss: 1.5653e-04
# Epoch 13/20
# 95/95 [==============================] - 2s 19ms/step - loss: 3.0329e-04 - val_loss: 1.4727e-04
# Epoch 14/20
# 95/95 [==============================] - 3s 30ms/step - loss: 3.1156e-04 - val_loss: 2.1794e-04
# Epoch 15/20
# 95/95 [==============================] - 4s 41ms/step - loss: 2.6516e-04 - val_loss: 1.4302e-04
# Epoch 16/20
# 95/95 [==============================] - 4s 45ms/step - loss: 2.7295e-04 - val_loss: 1.2943e-04
# Epoch 17/20
# 95/95 [==============================] - 4s 45ms/step - loss: 3.0924e-04 - val_loss: 1.3037e-04
# Epoch 18/20
# 95/95 [==============================] - 4s 44ms/step - loss: 2.5846e-04 - val_loss: 1.3923e-04
# Epoch 19/20
# 95/95 [==============================] - 4s 41ms/step - loss: 2.8639e-04 - val_loss: 2.0428e-04
# Epoch 20/20
# 95/95 [==============================] - 4s 43ms/step - loss: 2.8089e-04 - val_loss: 1.3835e-04
# 8/8 [==============================] - 1s 21ms/step

# %%
import pandas as pd # csv파일 로드용
import numpy as np # 행렬 연산용
import matplotlib.pyplot as plt # 데이터 시각화

#딥러닝 모델 작성 keras
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense, Activation
# from keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
import datetime



# Load Dataset
data = pd.read_csv('samsung.csv') #데이터 로드

# 날짜 컬럼을 datetime 타입으로 변환
data['Date'] = pd.to_datetime(data['Date'])

# 인덱스를 날짜로 설정
data.set_index('Date', inplace=True)

## Compute Mid Price
high_prices = data['High'].values
low_prices = data['Low'].values
mid_prices = (high_prices + low_prices) / 2 # 중간 가격 계산


# Create Windows
seq_len = 50
sequence_length = seq_len + 1 # 50개의 데이터 + 예측할 데이터 1개 (윈도우 하나에 51개의 데이터 저장)

result = []
for index in range(len(mid_prices) - sequence_length):
    result.append(mid_prices[index: index + sequence_length])


# Normalize Data (데이터 정규)
normalized_data = []
for window in result:
    normalized_window = [((float(p) / float(window[0])) - 1) for p in window]
    normalized_data.append(normalized_window)

result = np.array(normalized_data)

# split train and test data
row = int(round(result.shape[0] * 0.80))
train = result[:row, :] # 전체 데이터의 80%를 train set으로 분리함

# 윈도우마다 51개의 데이터가 들어있고
# 50개의 데이터를 input으로 나머지 1일의 데이터를 예측할 것임

x_train = train[:, :-1] # 50개
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = train[:, -1] # 마지막 1개

x_test = result[row:, :-1] # 50개
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
y_test = result[row:, -1] # 마지막 1개

x_train.shape, x_test.shape


# Build a Model
    
model = Sequential() # sequential이라는 class를 사용

model.add(LSTM(50, return_sequences=True, input_shape=(50, 1))) # input 50개 (units 50개)

model.add(LSTM(64, return_sequences=False)) # (units 64개)

model.add(Dense(1, activation='linear')) # ouput은 1개 - 다음날의 데이터 예측

model.compile(loss='mse', optimizer='adam') # 손실 함수는 Mean Squared Error 사용, optimizer는 rmsprop 사용

model.summary()


# Training
model.fit(x_train, y_train,
    validation_data=(x_test, y_test),
    batch_size=10,
    epochs=20)

# Recover the original prices instead of the scaled version
pred_result = []
y_test_result = []
for i in range(len(y_test)):
    pred_result.append((pred[i] + 1) * mid_prices[row + i])
    y_test_result.append((y_test[i] + 1) * mid_prices[row + i])


# Recover the original prices instead of the scaled version
pred_result = []
y_test_result = []
for i in range(len(y_test)):
    pred_result.append((pred[i] + 1) * mid_prices[row + i])
    y_test_result.append((y_test[i] + 1) * mid_prices[row + i])

# Prediction
pred = model.predict(x_test)

fig = plt.figure(facecolor='white', figsize=(20, 10)) 
ax = fig.add_subplot(111) 

# x축 데이터 생성
x_range = data.index[row+seq_len : row + len(y_test_result)+seq_len]

ax.plot(x_range, y_test_result, label='True')
ax.plot(x_range, pred_result, label='Prediction')
ax.legend()
plt.show()
# Out:
# Model: "sequential_47"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_94 (LSTM)              (None, 50, 50)            10400
#
#  lstm_95 (LSTM)              (None, 64)                29440
#
#  dense_47 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 39905 (155.88 KB)
# Trainable params: 39905 (155.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 95/95 [==============================] - 8s 55ms/step - loss: 0.0020 - val_loss: 5.0906e-04
# Epoch 2/20
# 95/95 [==============================] - 4s 43ms/step - loss: 9.8263e-04 - val_loss: 3.9937e-04
# Epoch 3/20
# 95/95 [==============================] - 4s 44ms/step - loss: 7.7121e-04 - val_loss: 3.6223e-04
# Epoch 4/20
# 95/95 [==============================] - 4s 38ms/step - loss: 6.9997e-04 - val_loss: 2.9348e-04
# Epoch 5/20
# 95/95 [==============================] - 4s 43ms/step - loss: 6.1431e-04 - val_loss: 3.1900e-04
# Epoch 6/20
# 95/95 [==============================] - 4s 39ms/step - loss: 5.7258e-04 - val_loss: 3.5826e-04
# Epoch 7/20
# 95/95 [==============================] - 4s 42ms/step - loss: 5.0090e-04 - val_loss: 2.2432e-04
# Epoch 8/20
# 95/95 [==============================] - 4s 39ms/step - loss: 4.4765e-04 - val_loss: 2.9497e-04
# Epoch 9/20
# 95/95 [==============================] - 4s 45ms/step - loss: 4.4918e-04 - val_loss: 1.9519e-04
# Epoch 10/20
# 95/95 [==============================] - 4s 43ms/step - loss: 3.7326e-04 - val_loss: 1.7315e-04
# Epoch 11/20
# 95/95 [==============================] - 4s 43ms/step - loss: 3.3424e-04 - val_loss: 1.6538e-04
# Epoch 12/20
# 95/95 [==============================] - 4s 40ms/step - loss: 3.0375e-04 - val_loss: 2.6734e-04
# Epoch 13/20
# 95/95 [==============================] - 4s 43ms/step - loss: 2.9980e-04 - val_loss: 1.5121e-04
# Epoch 14/20
# 95/95 [==============================] - 4s 38ms/step - loss: 2.7394e-04 - val_loss: 1.3489e-04
# Epoch 15/20
# 95/95 [==============================] - 4s 43ms/step - loss: 2.6203e-04 - val_loss: 1.4029e-04
# Epoch 16/20
# 95/95 [==============================] - 2s 20ms/step - loss: 2.5384e-04 - val_loss: 1.3652e-04
# Epoch 17/20
# 95/95 [==============================] - 2s 22ms/step - loss: 2.5327e-04 - val_loss: 1.2602e-04
# Epoch 18/20
# 95/95 [==============================] - 2s 22ms/step - loss: 2.4442e-04 - val_loss: 1.2392e-04
# Epoch 19/20
# 95/95 [==============================] - 2s 21ms/step - loss: 2.5964e-04 - val_loss: 1.5654e-04
# Epoch 20/20
# 95/95 [==============================] - 2s 26ms/step - loss: 2.4451e-04 - val_loss: 1.2653e-04
# 8/8 [==============================] - 1s 8ms/step

# %%
import pandas as pd
import matplotlib.pyplot as plt

# csv 파일 읽어오기
data = pd.read_csv('samsung.csv')

# 날짜를 datetime 형태로 변환
data['Date'] = pd.to_datetime(data['Date'])

# High와 Low의 평균값 계산하여 'Mid' 컬럼 생성
data['Mid'] = (data['High'] + data['Low']) / 2

# 데이터의 마지막 20% 추출
recent_data = data.tail(int(len(data) * 0.2))

# 시각화
plt.figure(figsize=(20,10))
plt.plot(recent_data['Date'], recent_data['Mid'])
plt.xlabel('Date')
plt.ylabel('Mid Price')
plt.title('Samsung Stock Price')
plt.show()

# %%
import pandas as pd # csv파일 로드용
import numpy as np # 행렬 연산용
import matplotlib.pyplot as plt # 데이터 시각화

#딥러닝 모델 작성 keras
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense, Activation
# from keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
import datetime



# Load Dataset
data = pd.read_csv('samsung.csv') #데이터 로드

# 날짜 컬럼을 datetime 타입으로 변환
data['Date'] = pd.to_datetime(data['Date'])

# 인덱스를 날짜로 설정
data.set_index('Date', inplace=True)

## Compute Mid Price
high_prices = data['High'].values
low_prices = data['Low'].values
mid_prices = (high_prices + low_prices) / 2 # 중간 가격 계산


# Create Windows
seq_len = 50
sequence_length = seq_len + 1 # 50개의 데이터 + 예측할 데이터 1개 (윈도우 하나에 51개의 데이터 저장)

result = []
for index in range(len(mid_prices) - sequence_length):
    result.append(mid_prices[index: index + sequence_length])


# Normalize Data (데이터 정규)
normalized_data = []
for window in result:
    normalized_window = [((float(p) / float(window[0])) - 1) for p in window]
    normalized_data.append(normalized_window)

result = np.array(normalized_data)

# split train and test data
row = int(round(result.shape[0] * 1))
train = result[:row, :] # 전체 데이터의 100%를 train set으로 분리함

# 윈도우마다 51개의 데이터가 들어있고
# 50개의 데이터를 input으로 나머지 1일의 데이터를 예측할 것임

x_train = train[:, :-1] # 50개
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = train[:, -1] # 마지막 1개

# x_test = result[row:, :-1] # 50개
# x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
# y_test = result[row:, -1] # 마지막 1개

# x_train.shape, x_test.shape


# Build a Model
    
model = Sequential() # sequential이라는 class를 사용

model.add(LSTM(50, return_sequences=True, input_shape=(50, 1))) # input 50개 (units 50개)

model.add(LSTM(64, return_sequences=False)) # (units 64개)

model.add(Dense(1, activation='linear')) # ouput은 1개 - 다음날의 데이터 예측

model.compile(loss='mse', optimizer='adam') # 손실 함수는 Mean Squared Error 사용, optimizer는 rmsprop 사용

model.summary()


# Training
model.fit(x_train, y_train,
    batch_size=10,
    epochs=20)

# Recover the original prices instead of the scaled version
pred_result = []
y_test_result = []
for i in range(len(y_test)):
    pred_result.append((pred[i] + 1) * mid_prices[row + i])
    y_test_result.append((y_test[i] + 1) * mid_prices[row + i])


# Recover the original prices instead of the scaled version
pred_result = []
y_test_result = []
for i in range(len(y_test)):
    pred_result.append((pred[i] + 1) * mid_prices[row + i])
    y_test_result.append((y_test[i] + 1) * mid_prices[row + i])

# Prediction
pred = model.predict(x_test)

fig = plt.figure(facecolor='white', figsize=(20, 10)) 
ax = fig.add_subplot(111) 

# x축 데이터 생성
x_range = data.index[row+seq_len : row + len(y_test_result)+seq_len]

ax.plot(x_range, y_test_result, label='True')
ax.plot(x_range, pred_result, label='Prediction')
ax.legend()
plt.show()
